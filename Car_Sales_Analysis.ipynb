# %% [markdown]
# <a href="https://colab.research.google.com/github/raju1207/Car_Sales_Analysis/blob/main/Car_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Car_sales.csv')
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.iloc[4]
# Out:
# Manufacturer                Audi
# Model                         A4
# Sales_in_thousands        20.397
# __year_resale_value       22.255
# Vehicle_type           Passenger
# Price_in_thousands         23.99
# Engine_size                  1.8
# Horsepower                 150.0
# Wheelbase                  102.6
# Width                       68.2
# Length                     178.0
# Curb_weight                2.998
# Fuel_capacity               16.4
# Fuel_efficiency             27.0
# Latest_Launch          10/8/2011
# Power_perf_factor      62.777639
# Name: 4, dtype: object

# %%
df.iloc[3:6]
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 3        Acura    RL               8.588               29.725    Passenger
# 4         Audi    A4              20.397               22.255    Passenger
# 5         Audi    A6              18.780               23.555    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 3        3.850           18.0             22.0     3/10/2011
# 4        2.998           16.4             27.0     10/8/2011
# 5        3.561           18.5             22.0      8/9/2011
#
#    Power_perf_factor
# 3          91.389779
# 4          62.777639
# 5          84.565105

# %%
df.iloc[3:40]
# Out:
#    Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 3         Acura              RL               8.588               29.725
# 4          Audi              A4              20.397               22.255
# 5          Audi              A6              18.780               23.555
# 6          Audi              A8               1.380               39.000
# 7           BMW            323i              19.747                  NaN
# 8           BMW            328i               9.231               28.675
# 9           BMW            528i              17.527               36.125
# 10        Buick         Century              91.561               12.475
# 11        Buick           Regal              39.350               13.740
# 12        Buick     Park Avenue              27.851               20.190
# 13        Buick         LeSabre              83.257               13.360
# 14     Cadillac         DeVille              63.729               22.525
# ...

# %%
df.iloc[3:76,5:14]
# Out:
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 3               42.000          3.5       210.0      114.6   71.4   196.6
# 4               23.990          1.8       150.0      102.6   68.2   178.0
# 5               33.950          2.8       200.0      108.7   76.1   192.0
# 6               62.000          4.2       310.0      113.0   74.0   198.2
# 7               26.990          2.5       170.0      107.3   68.4   176.0
# ..                 ...          ...         ...        ...    ...     ...
# 71              37.805          3.0       225.0      110.2   70.9   189.2
# 72              46.305          4.0       300.0      110.2   70.9   189.2
# 73              54.005          4.0       290.0      112.2   72.0   196.7
# 74              60.105          4.7       230.0      112.2   76.4   192.5
# 75              34.605          3.0       220.0      103.0   71.5   180.1
#
#     Curb_weight  Fuel_capacity  Fuel_efficiency
# ...

# %%
df.iloc[[20,34,55,66,89,9],[3,5,9,8]]
# Out:
#     __year_resale_value  Price_in_thousands  Width  Wheelbase
# 20               11.225              16.535   69.4      107.0
# 34                  NaN              29.185   74.4      113.0
# 55                7.850              12.050   69.4      117.5
# 66                  NaN              42.800   71.6      114.5
# 89               14.875              22.605   78.2      114.7
# 9                36.125              38.900   70.9      111.4

# %%
df.iloc[:,7]
# Out:
# 0      140.0
# 1      225.0
# 2      225.0
# 3      210.0
# 4      150.0
#        ...
# 152    160.0
# 153    168.0
# 154    168.0
# 155    236.0
# 156    201.0
# Name: Horsepower, Length: 157, dtype: float64

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
df.loc[3:7,['Width', 'Length']]
# Out:
#    Width  Length
# 3   71.4   196.6
# 4   68.2   178.0
# 5   76.1   192.0
# 6   74.0   198.2
# 7   68.4   176.0

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.set_index("Model")
# Out:
#         Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# Model
# Integra        Acura              16.919               16.360    Passenger
# TL             Acura              39.384               19.875    Passenger
# CL             Acura              14.114               18.225    Passenger
# RL             Acura               8.588               29.725    Passenger
# A4              Audi              20.397               22.255    Passenger
# ...              ...                 ...                  ...          ...
# V40            Volvo               3.545                  NaN    Passenger
# S70            Volvo              15.245                  NaN    Passenger
# V70            Volvo              17.531                  NaN    Passenger
# C70            Volvo               3.493                  NaN    Passenger
# S80            Volvo              18.969                  NaN    Passenger
#
# ...

# %%
df.set_index("Model",inplace=True)  #dont run 2 times
df
# Out:
#         Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# Model
# Integra        Acura              16.919               16.360    Passenger
# TL             Acura              39.384               19.875    Passenger
# CL             Acura              14.114               18.225    Passenger
# RL             Acura               8.588               29.725    Passenger
# A4              Audi              20.397               22.255    Passenger
# ...              ...                 ...                  ...          ...
# V40            Volvo               3.545                  NaN    Passenger
# S70            Volvo              15.245                  NaN    Passenger
# V70            Volvo              17.531                  NaN    Passenger
# C70            Volvo               3.493                  NaN    Passenger
# S80            Volvo              18.969                  NaN    Passenger
#
# ...

# %%
df.loc["S70":"C70"]
# Out:
#       Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# Model
# S70          Volvo              15.245                  NaN    Passenger
# V70          Volvo              17.531                  NaN    Passenger
# C70          Volvo               3.493                  NaN    Passenger
#
#        Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# Model
# S70                  27.5          2.4       168.0      104.9   69.3   185.9
# V70                  28.8          2.4       168.0      104.9   69.3   186.2
# C70                  45.5          2.3       236.0      104.9   71.5   185.7
#
#        Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# Model
# S70          3.208           17.9             25.0    11/24/2012
# V70          3.259           17.9             25.0     6/25/2011
# C70          3.601           18.5             23.0     4/26/2011
#
#        Power_perf_factor
# Model
# S70            70.654495
# ...

# %%
df.iloc[-4:-1]
# Out:
#       Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# Model
# S70          Volvo              15.245                  NaN    Passenger
# V70          Volvo              17.531                  NaN    Passenger
# C70          Volvo               3.493                  NaN    Passenger
#
#        Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# Model
# S70                  27.5          2.4       168.0      104.9   69.3   185.9
# V70                  28.8          2.4       168.0      104.9   69.3   186.2
# C70                  45.5          2.3       236.0      104.9   71.5   185.7
#
#        Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# Model
# S70          3.208           17.9             25.0    11/24/2012
# V70          3.259           17.9             25.0     6/25/2011
# C70          3.601           18.5             23.0     4/26/2011
#
#        Power_perf_factor
# Model
# S70            70.654495
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, Integra to S80
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Sales_in_thousands   157 non-null    float64
#  2   __year_resale_value  121 non-null    float64
#  3   Vehicle_type         157 non-null    object
#  4   Price_in_thousands   155 non-null    float64
#  5   Engine_size          156 non-null    float64
#  6   Horsepower           156 non-null    float64
#  7   Wheelbase            156 non-null    float64
#  8   Width                156 non-null    float64
#  9   Length               156 non-null    float64
#  10  Curb_weight          155 non-null    float64
#  11  Fuel_capacity        156 non-null    float64
#  12  Fuel_efficiency      154 non-null    float64
#  13  Latest_Launch        157 non-null    object
#  14  Power_perf_factor    155 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
df.describe(include="all")
# Out:
#        Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# count           157          157.000000           121.000000          157
# unique           30                 NaN                  NaN            2
# top           Dodge                 NaN                  NaN    Passenger
# freq             11                 NaN                  NaN          116
# mean            NaN           52.998076            18.072975          NaN
# std             NaN           68.029422            11.453384          NaN
# min             NaN            0.110000             5.160000          NaN
# 25%             NaN           14.114000            11.260000          NaN
# 50%             NaN           29.450000            14.180000          NaN
# 75%             NaN           67.956000            19.875000          NaN
# max             NaN          540.561000            67.550000          NaN
#
#         Price_in_thousands  Engine_size  Horsepower   Wheelbase       Width  \
# ...

# %%
df["Manufacturer"].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
df["Manufacturer"].nunique()
# Out:
# 30

# %%
df.Manufacturer.unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
df.shape
# Out:
# (157, 15)

# %%
pd.set_option("display.max_rows",None)

# %%
df
# Out:
#                Manufacturer  Sales_in_thousands  __year_resale_value  \
# Model
# Integra               Acura              16.919               16.360
# TL                    Acura              39.384               19.875
# CL                    Acura              14.114               18.225
# RL                    Acura               8.588               29.725
# A4                     Audi              20.397               22.255
# A6                     Audi              18.780               23.555
# A8                     Audi               1.380               39.000
# 323i                    BMW              19.747                  NaN
# 328i                    BMW               9.231               28.675
# 528i                    BMW              17.527               36.125
# Century               Buick              91.561               12.475
# Regal                 Buick              39.350               13.740
# ...

# %%
df[df["Manufacturer"]=="Toyota"]
# Out:
#              Manufacturer  Sales_in_thousands  __year_resale_value  \
# Model
# Corolla            Toyota             142.535               10.025
# Camry              Toyota             247.994               13.245
# Avalon             Toyota              63.849               18.140
# Celica             Toyota              33.269               15.445
# Tacoma             Toyota              84.087                9.575
# Sienna             Toyota              65.119                  NaN
# RAV4               Toyota              25.106               13.325
# 4Runner            Toyota              68.411               19.425
# Land Cruiser       Toyota               9.835               34.080
#
#              Vehicle_type  Price_in_thousands  Engine_size  Horsepower  \
# Model
# Corolla         Passenger              13.108          1.8       120.0
# Camry           Passenger              17.518          2.2       133.0
# ...

# %%
df[df["Vehicle_type"]=="Passenger"]
# Out:
#                Manufacturer  Sales_in_thousands  __year_resale_value  \
# Model
# Integra               Acura              16.919               16.360
# TL                    Acura              39.384               19.875
# CL                    Acura              14.114               18.225
# RL                    Acura               8.588               29.725
# A4                     Audi              20.397               22.255
# A6                     Audi              18.780               23.555
# A8                     Audi               1.380               39.000
# 323i                    BMW              19.747                  NaN
# 328i                    BMW               9.231               28.675
# 528i                    BMW              17.527               36.125
# Century               Buick              91.561               12.475
# Regal                 Buick              39.350               13.740
# ...

# %%
df[(df["Manufacturer"]=="Toyota") & (df["Vehicle_type"]=="Passenger")]
# Out:
#         Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# Model
# Corolla       Toyota             142.535               10.025    Passenger
# Camry         Toyota             247.994               13.245    Passenger
# Avalon        Toyota              63.849               18.140    Passenger
# Celica        Toyota              33.269               15.445    Passenger
#
#          Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# Model
# Corolla              13.108          1.8       120.0       97.0   66.7
# Camry                17.518          2.2       133.0      105.2   70.1
# Avalon               25.545          3.0       210.0      107.1   71.7
# Celica               16.875          1.8       140.0      102.4   68.3
#
#          Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# Model
# Corolla   174.0        2.420           13.2             33.0     4/11/2011
# ...

# %%
df[(df["Manufacturer"]=="Toyota") | (df["Vehicle_type"]=="Passenger")]
# Out:
#                Manufacturer  Sales_in_thousands  __year_resale_value  \
# Model
# Integra               Acura              16.919               16.360
# TL                    Acura              39.384               19.875
# CL                    Acura              14.114               18.225
# RL                    Acura               8.588               29.725
# A4                     Audi              20.397               22.255
# A6                     Audi              18.780               23.555
# A8                     Audi               1.380               39.000
# 323i                    BMW              19.747                  NaN
# 328i                    BMW               9.231               28.675
# 528i                    BMW              17.527               36.125
# Century               Buick              91.561               12.475
# Regal                 Buick              39.350               13.740
# ...

# %%
df[df["Horsepower"]>=200]
# Out:
#                Manufacturer  Sales_in_thousands  __year_resale_value  \
# Model
# TL                    Acura              39.384               19.875
# CL                    Acura              14.114               18.225
# RL                    Acura               8.588               29.725
# A6                     Audi              18.780               23.555
# A8                     Audi               1.380               39.000
# Regal                 Buick              39.350               13.740
# Park Avenue           Buick              27.851               20.190
# LeSabre               Buick              83.257               13.360
# DeVille            Cadillac              63.729               22.525
# Seville            Cadillac              15.943               27.100
# Eldorado           Cadillac               6.536               25.725
# Catera             Cadillac              11.185               18.225
# ...

# %%
df[df["Horsepower"].between(200,220)]
# Out:
#                Manufacturer  Sales_in_thousands  __year_resale_value  \
# Model
# RL                    Acura               8.588               29.725
# A6                     Audi              18.780               23.555
# Park Avenue           Buick              27.851               20.190
# LeSabre               Buick              83.257               13.360
# Catera             Cadillac              11.185               18.225
# Camaro            Chevrolet              26.402               13.025
# Concorde           Chrysler              31.148               13.725
# Intrepid              Dodge              88.028               12.275
# Crown Victoria         Ford              63.403               14.210
# Explorer               Ford             276.747               16.640
# F-Series               Ford             540.561               15.075
# Passport              Honda              12.855               17.525
# ...

# %%
df["Vehicle_type"].value_counts()
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
df[df["Horsepower"].between(200,220)]["Vehicle_type"].value_counts()
# Out:
# Vehicle_type
# Passenger    20
# Car           8
# Name: count, dtype: int64

# %%
df[df["Manufacturer"].isin(["Toyota","Honda"])]
# Out:
#              Manufacturer  Sales_in_thousands  __year_resale_value  \
# Model
# Civic               Honda             199.685                9.850
# Accord              Honda             230.902               13.210
# CR-V                Honda              73.203               17.710
# Passport            Honda              12.855               17.525
# Odyssey             Honda              76.029               19.490
# Corolla            Toyota             142.535               10.025
# Camry              Toyota             247.994               13.245
# Avalon             Toyota              63.849               18.140
# Celica             Toyota              33.269               15.445
# Tacoma             Toyota              84.087                9.575
# Sienna             Toyota              65.119                  NaN
# RAV4               Toyota              25.106               13.325
# 4Runner            Toyota              68.411               19.425
# ...

# %%
df[df["Manufacturer"].isin(["Toyota","Honda"])].loc[:,["Engine_size","Wheelbase"]]
# Out:
#               Engine_size  Wheelbase
# Model
# Civic                 1.6      103.2
# Accord                2.3      106.9
# CR-V                  2.0      103.2
# Passport              3.2      106.4
# Odyssey               3.5      118.1
# Corolla               1.8       97.0
# Camry                 2.2      105.2
# Avalon                3.0      107.1
# Celica                1.8      102.4
# Tacoma                2.4      103.3
# Sienna                3.0      114.2
# RAV4                  2.0       94.9
# 4Runner               2.7      105.3
# Land Cruiser          4.7      112.2

# %%
df[df["Manufacturer"].isin(["Toyota","Honda"])].value_counts("Manufacturer")
# Out:
# Manufacturer
# Toyota    9
# Honda     5
# Name: count, dtype: int64

# %%
df[df["Manufacturer"].isin(["Toyota","Honda"])].value_counts()
# Out:
# Manufacturer  Sales_in_thousands  __year_resale_value  Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency  Latest_Launch  Power_perf_factor
# Honda         12.855              17.525               Car           26.600              3.2          205.0       106.4      70.4   178.2   3.857        21.1           19.0             10/9/2012      83.602501            1
#               73.203              17.710               Car           20.550              2.0          146.0       103.2      68.9   177.6   3.219        15.3           24.0             3/21/2012      60.087967            1
#               76.029              19.490               Car           26.000              3.5          210.0       118.1      75.6   201.2   4.288        20.0           23.0             2/8/2012       85.217691            1
# ...

# %%
df.sort_values(by=["Manufacturer"],ascending=False)
# Out:
#                Manufacturer  Sales_in_thousands  __year_resale_value  \
# Model
# S80                   Volvo              18.969                  NaN
# C70                   Volvo               3.493                  NaN
# V70                   Volvo              17.531                  NaN
# S70                   Volvo              15.245                  NaN
# V40                   Volvo               3.545                  NaN
# S40                   Volvo              16.957                  NaN
# Beetle           Volkswagen              49.463                  NaN
# GTI              Volkswagen               5.596               13.760
# Cabrio           Volkswagen               9.569               16.575
# Passat           Volkswagen              51.102               16.725
# Jetta            Volkswagen              83.721               13.240
# Golf             Volkswagen               9.761               11.425
# ...

# %%
df.sort_values(by=["Manufacturer","Vehicle_type","Horsepower","Price_in_thousands"],ascending=[False,True,False,True])
# Out:
#                Manufacturer  Sales_in_thousands  __year_resale_value  \
# Model
# C70                   Volvo               3.493                  NaN
# S80                   Volvo              18.969                  NaN
# S70                   Volvo              15.245                  NaN
# V70                   Volvo              17.531                  NaN
# S40                   Volvo              16.957                  NaN
# V40                   Volvo               3.545                  NaN
# Passat           Volkswagen              51.102               16.725
# Golf             Volkswagen               9.761               11.425
# Beetle           Volkswagen              49.463                  NaN
# Jetta            Volkswagen              83.721               13.240
# GTI              Volkswagen               5.596               13.760
# Cabrio           Volkswagen               9.569               16.575
# ...

# %%
pd.set_option("display.max_rows",None)

# %%
df.sort_values(by=["Manufacturer","Vehicle_type","Horsepower","Price_in_thousands"],ascending=[False,True,False,True])
# Out:
#                Manufacturer  Sales_in_thousands  __year_resale_value  \
# Model
# C70                   Volvo               3.493                  NaN
# S80                   Volvo              18.969                  NaN
# S70                   Volvo              15.245                  NaN
# V70                   Volvo              17.531                  NaN
# S40                   Volvo              16.957                  NaN
# V40                   Volvo               3.545                  NaN
# Passat           Volkswagen              51.102               16.725
# Golf             Volkswagen               9.761               11.425
# Beetle           Volkswagen              49.463                  NaN
# Jetta            Volkswagen              83.721               13.240
# GTI              Volkswagen               5.596               13.760
# Cabrio           Volkswagen               9.569               16.575
# ...

# %%
df.sort_values(by=["Manufacturer","Vehicle_type","Horsepower","Price_in_thousands"],ascending=[False,True,False,True]).loc[:,["Manufacturer","Vehicle_type","Horsepower","Price_in_thousands"]]
# Out:
#                Manufacturer Vehicle_type  Horsepower  Price_in_thousands
# Model
# C70                   Volvo    Passenger       236.0              45.500
# S80                   Volvo    Passenger       201.0              36.000
# S70                   Volvo    Passenger       168.0              27.500
# V70                   Volvo    Passenger       168.0              28.800
# S40                   Volvo    Passenger       160.0              23.400
# V40                   Volvo    Passenger       160.0              24.400
# Passat           Volkswagen    Passenger       150.0              21.200
# Golf             Volkswagen    Passenger       115.0              14.900
# Beetle           Volkswagen    Passenger       115.0              15.900
# Jetta            Volkswagen    Passenger       115.0              16.700
# GTI              Volkswagen    Passenger       115.0              17.500
# Cabrio           Volkswagen    Passenger       115.0              19.990
# ...

# %%
df.groupby("Manufacturer")

# %%
df.groupby("Manufacturer")["Sales_in_thousands"]

# %%
df.groupby("Manufacturer")["Sales_in_thousands"].mean()
# Out:
# Manufacturer
# Acura          19.751250
# Audi           13.519000
# BMW            15.501667
# Buick          60.504750
# Cadillac       22.435600
# Chevrolet      61.596111
# Chrysler       28.817286
# Dodge          82.740818
# Ford          183.875909
# Honda         118.534800
# Hyundai        45.775333
# Infiniti       23.713000
# Jaguar         15.467000
# Jeep           97.717667
# Lexus          17.807167
# Lincoln        28.544667
# Mercedes-B     13.013889
# Mercury        39.666500
# Mitsubishi     25.842143
# Nissan         57.090714
# Oldsmobile     29.831500
# Plymouth       16.000250
# Pontiac        61.755667
# Porsche         4.042667
# Saab           10.653000
# Saturn         33.770000
# Subaru         40.067500
# Toyota         82.245000
# Volkswagen     34.868667
# Volvo          12.623333
# Name: Sales_in_thousands, dtype: float64

# %%
df.groupby("Manufacturer")["Sales_in_thousands"].sum()
# Out:
# Manufacturer
# Acura           79.005
# Audi            40.557
# BMW             46.505
# Buick          242.019
# Cadillac       112.178
# Chevrolet      554.365
# Chrysler       201.721
# Dodge          910.149
# Ford          2022.635
# Honda          592.674
# Hyundai        137.326
# Infiniti        23.713
# Jaguar          15.467
# Jeep           293.153
# Lexus          106.843
# Lincoln         85.634
# Mercedes-B     117.125
# Mercury        237.999
# Mitsubishi     180.895
# Nissan         399.635
# Oldsmobile     178.989
# Plymouth        64.001
# Pontiac        370.534
# Porsche         12.128
# Saab            21.306
# Saturn         168.850
# Subaru          80.135
# Toyota         740.205
# Volkswagen     209.212
# Volvo           75.740
# Name: Sales_in_thousands, dtype: float64

# %%
df.head()
# Out:
#         Manufacturer  Sales_in_thousands  __year_resale_value Vehicle_type  \
# Model
# Integra        Acura              16.919               16.360    Passenger
# TL             Acura              39.384               19.875    Passenger
# CL             Acura              14.114               18.225    Passenger
# RL             Acura               8.588               29.725    Passenger
# A4              Audi              20.397               22.255    Passenger
#
#          Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# Model
# Integra               21.50          1.8       140.0      101.2   67.3
# TL                    28.40          3.2       225.0      108.1   70.3
# CL                      NaN          3.2       225.0      106.9   70.6
# RL                    42.00          3.5       210.0      114.6   71.4
# A4                    23.99          1.8       150.0      102.6   68.2
#
# ...

# %%
df[df["Vehicle_type"]=="Passenger"].groupby("Manufacturer")["Engine_size"].min()
# Out:
# Manufacturer
# Acura         1.8
# Audi          1.8
# BMW           2.5
# Buick         3.1
# Cadillac      3.0
# Chevrolet     1.0
# Chrysler      2.0
# Dodge         2.0
# Ford          2.0
# Honda         1.6
# Hyundai       1.5
# Infiniti      3.0
# Jaguar        3.0
# Lexus         3.0
# Lincoln       4.6
# Mercedes-B    2.3
# Mercury       2.0
# Mitsubishi    1.8
# Nissan        1.8
# Oldsmobile    2.4
# Plymouth      2.0
# Pontiac       2.4
# Porsche       2.7
# Saab          2.0
# Saturn        1.9
# Subaru        2.5
# Toyota        1.8
# Volkswagen    1.8
# Volvo         1.9
# Name: Engine_size, dtype: float64
